# %% [markdown]
# # Exploration Notes

# %% [markdown]
# Oh this one has so many fun moments! There's this one, right now. Where my kernal didn't shut down effectively so I'm having to re-type the notebook (at least I can clean while I re-type, and it wasn't as bad as it could have been!)
#
# There's me struggling all day to finally find a function that works, to find out that Raf shared a way to do just that in the first two minutes of the Violin Plots video! That's alright, I just keep repeating my mantra for the week: "It's not wasted time if you learned something.... right?!"
#
# First, I pull in the dfGenreFin info and the unique genres list. I dropped unnecessary columns, and we decided on our main list of genres.
#
# Then I graphed the mean gross by genre and the mean production budget by genre; along with the top 7 and 5 from each.
#
# Then I tried playing around with Seaborn, and attempted to chart the two of these together. That's when I realized that I was going to have to stack the data by Genre - which took another frustratingly long time to pull a dataframe together for.
#
# Alas! We have persevered, and managed to plot an ugly little violin chart that displays the instances of ROI on the top 5 grossing genres(mean).
#
# We charted the ROI for the most popular genres, as well as for the top grossing genres in order to choose our top 5 performing genres overall.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# %store -r dfGenreFin

# %%
dfGenreFin.rename(columns = {'index' : 'title'}, inplace = True)
dfGenreFin.head()
# Out:
#                     title studio  domestic_gross  foreign_gross    year  \
# 0                     '71  RAtt.       1300000.0       355000.0  2015.0
# 1  1,000 Times Good Night     FM         53900.0            0.0  2014.0
# 2     10 Cloverfield Lane   Par.      72100000.0     38100000.0  2016.0
# 3   10 Days in a Madhouse    NaN         14616.0            0.0     NaN
# 4                10 Years  Anch.        203000.0            0.0  2012.0
#
#    release_date  production_budget  worldwide_gross         original_title  \
# 0           NaN                0.0        1655000.0                    '71
# 1           NaN                0.0          53900.0  Tusen ganger god natt
# 2  Mar 11, 2016          5000000.0      108286422.0    10 Cloverfield Lane
# 3  Nov 11, 2015         12000000.0          14616.0  10 Days in a Madhouse
# 4           NaN                0.0         203000.0               10 Years
#
#    start_year  runtime_minutes  averagerating  numvotes   movie_id  \
# 0      2014.0             99.0            7.2   46103.0  tt2614684
# 1      2013.0            117.0            7.1    6848.0  tt2353767
# 2      2016.0            103.0            7.2  260383.0  tt1179933
# 3      2015.0            111.0            6.7    1114.0  tt3453052
# 4      2011.0            100.0            6.1   22484.0  tt1715873
#
#                   genresList
# 0  [Action, Drama, Thriller]
# 1               [Drama, War]
# 2   [Drama, Horror, Mystery]
# 3                    [Drama]
# 4   [Comedy, Drama, Romance]

# %% [markdown]
# - Pulling in list of unique genres

# %%
# %store -r oneGenreList

# %%
uniqueGenres = oneGenreList['genres'].unique()

# %%
uniqueGenres
# Out:
# array(['Drama', 'Comedy', 'Biography', 'History', 'Documentary', 'Sci-Fi',
#        'Thriller', 'Horror', 'Action', 'Adventure', 'Fantasy', 'Musical',
#        'Western', 'Romance', 'Mystery', 'Crime', 'Animation', 'Family',
#        'Sport', 'Music', 'News', 'Talk-Show', 'Reality-TV', 'War',
#        'Game-Show'], dtype=object)

# %%
len(uniqueGenres)
# Out:
# 25

# %% [markdown]
# # Getting information ready for plotting

# %% [markdown]
# - Or so I thought!

# %%
from importlib import reload
import functions as fun

reload(fun)
# Out:
# <module 'functions' from 'C:\\Users\\kekay\\flatiron\\Module01\\Project\\dsc-mod-1-project-v2-1-onl01-dtsc-ft-041320\\functions.py'>

# %%
fun.count('News', dfGenreFin)
# Out:
# 11

# %% [markdown]
# Ignore:
# - Game-Show : 0
# - Reality-TV : 0
# - Talk-Show : 0
# - News : 11 (Featured in other genres as well)

# %%
genreList = ['Action', 'Adventure', 'Animation', 'Biography', 'Drama', 'Comedy', 'History', 
             'Documentary', 'Sci-Fi', 'Thriller', 'Horror', 'Fantasy', 'Musical', 'Western', 'Romance', 
             'Mystery', 'Crime', 'Family', 'Sport', 'Music', 'War']

# %%
genreList.sort()
genreList
# Out:
# ['Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western']

# %%
# %store genreList
# Out:
# Stored 'genreList' (list)

# %% [markdown]
# # Mean Gross by Genre

# %%
def getMeanGrossData():
    data = []
    for i in genreList:
        data.append(fun.meanGross(i, dfGenreFin))
    return data

# %%
meanGrossData = getMeanGrossData()

# %%
meanGrossData
# Out:
# [54043316.219251335,
#  88147457.58236273,
#  83692006.28921568,
#  21693540.207407407,
#  33302470.265402842,
#  23121060.36642599,
#  23248293.022421524,
#  19737887.80093761,
#  60032657.344827585,
#  66945316.448275864,
#  19700843.310526315,
#  27129086.14412417,
#  35340738.59550562,
#  82193277.88636364,
#  24146523.306060605,
#  17938810.294209704,
#  82307881.88936171,
#  28450808.24742268,
#  27549630.76994681,
#  14440282.333333334,
#  24682976.085714284]

# %%
grossData = pd.DataFrame({'Genre' : genreList,
                          'Mean Gross' : meanGrossData,})

grossData
# %store grossData
# Out:
# Stored 'grossData' (DataFrame)

# %%
data = meanGrossData
labels = genreList
plt.xticks(range(len(data)), labels, rotation= 90)
plt.xlabel('Genres')
plt.ylabel('Mean Gross')
plt.title('Mean Gross by Genre')
bar_list = plt.bar(range(len(data)), data)



bar_list[0].set_color('r')
plt.show()

# %% [markdown]
# - ^ It's definitely gross!

# %%
g = sns.catplot(x="Genre", y="Mean Gross", kind="bar", palette="ch:.25", data= grossData);
g.set_xticklabels(rotation = 90)
g.fig.suptitle('Mean Gross by Genre')
plt.show()

# %%
top7GrossingGenres = grossData.loc[grossData['Mean Gross'] >= grossData['Mean Gross'][0]]
top5GrossingGenres = grossData.loc[grossData['Mean Gross'] >= grossData['Mean Gross'][9]]
# %store top7GrossingGenres
# Out:
# Stored 'top7GrossingGenres' (DataFrame)

# %%
g = sns.catplot(x="Genre", y="Mean Gross", kind="bar", palette =("ch:.25"), data= top7GrossingGenres);
g.set_xticklabels(rotation = 90)
g.fig.suptitle('Mean Gross by Genre: Top 7')
plt.show()

# %% [markdown]
# # Mean Production Budget by Genre

# %%
def getMeanBudgetData():
    data = []
    for i in genreList:
        data.append(fun.meanBudget(i, dfGenreFin))
    return data

# %%
meanBudgetData = getMeanBudgetData()

# %%
budgetData = pd.DataFrame({'Genre' : genreList,
                           'Mean Gross' : meanGrossData,
                           'Mean Budget' : meanBudgetData})

budgetData
# Out:
#           Genre    Mean Gross   Mean Budget
# 0        Action  5.404332e+07  4.673630e+07
# 1     Adventure  8.814746e+07  7.063706e+07
# 2     Animation  8.369201e+07  5.766503e+07
# 3     Biography  2.169354e+07  1.519645e+07
# 4        Comedy  3.330247e+07  2.178094e+07
# 5         Crime  2.312106e+07  1.921784e+07
# 6   Documentary  2.324829e+07  1.833320e+07
# 7         Drama  1.973789e+07  1.521898e+07
# 8        Family  6.003266e+07  4.037878e+07
# 9       Fantasy  6.694532e+07  5.043849e+07
# 10      History  1.970084e+07  1.639611e+07
# 11       Horror  2.712909e+07  1.672972e+07
# 12        Music  3.534074e+07  1.478320e+07
# 13      Musical  8.219328e+07  3.115203e+07
# 14      Mystery  2.414652e+07  1.654571e+07
# 15      Romance  1.793881e+07  1.180942e+07
# 16       Sci-Fi  8.230788e+07  6.229495e+07
# 17        Sport  2.845081e+07  1.905361e+07
# 18     Thriller  2.754963e+07  2.084044e+07
# 19          War  1.444028e+07  1.391111e+07
# 20      Western  2.468298e+07  2.444429e+07

# %%
def getMeanROI():
    meanROI = []
    for i in budgetData.index:
        ROI = ((budgetData['Mean Gross'][i])/(budgetData['Mean Budget'][i])) *100
        meanROI.append(ROI)
    return meanROI

# %%
budgetData['Mean ROI'] = getMeanROI()
budgetData
# Out:
#           Genre    Mean Gross   Mean Budget    Mean ROI
# 0        Action  5.404332e+07  4.673630e+07  115.634558
# 1     Adventure  8.814746e+07  7.063706e+07  124.789256
# 2     Animation  8.369201e+07  5.766503e+07  145.134761
# 3     Biography  2.169354e+07  1.519645e+07  142.753963
# 4        Comedy  3.330247e+07  2.178094e+07  152.897333
# 5         Crime  2.312106e+07  1.921784e+07  120.310381
# 6   Documentary  2.324829e+07  1.833320e+07  126.809798
# 7         Drama  1.973789e+07  1.521898e+07  129.692547
# 8        Family  6.003266e+07  4.037878e+07  148.673784
# 9       Fantasy  6.694532e+07  5.043849e+07  132.726656
# 10      History  1.970084e+07  1.639611e+07  120.155628
# 11       Horror  2.712909e+07  1.672972e+07  162.161015
# 12        Music  3.534074e+07  1.478320e+07  239.060172
# 13      Musical  8.219328e+07  3.115203e+07  263.845670
# 14      Mystery  2.414652e+07  1.654571e+07  145.938253
# 15      Romance  1.793881e+07  1.180942e+07  151.902579
# 16       Sci-Fi  8.230788e+07  6.229495e+07  132.126098
# 17        Sport  2.845081e+07  1.905361e+07  149.319792
# 18     Thriller  2.754963e+07  2.084044e+07  132.193157
# 19          War  1.444028e+07  1.391111e+07  103.803946
# 20      Western  2.468298e+07  2.444429e+07  100.976467

# %%
g = sns.catplot(x="Genre", y="Mean Budget", kind="bar", palette="ch:.25", data= budgetData);
g.set_xticklabels(rotation = 90)
g.fig.suptitle('Mean Production Budget by Genre')
plt.show()

# %%
top7GenreBudgets = budgetData.loc[budgetData['Mean Budget'] >= budgetData['Mean Budget'][13]]
top5GenreBudgets = budgetData.loc[budgetData['Mean Budget'] >= budgetData['Mean Budget'][0]]
# %store top5GenreBudgets
# Out:
# Stored 'top5GenreBudgets' (DataFrame)

# %%
g = sns.catplot(x="Genre", y="Mean Budget", kind="bar", palette="ch:.25", data= top5GenreBudgets);
g.set_xticklabels(rotation = 90)
g.fig.suptitle('Mean Production Budget by Genre: Top 5')
plt.show()

# %% [markdown]
# # Try to graph both mean gross and mean budget

# %%
meanData = pd.DataFrame({'Genre' : genreList,
                         'Mean Gross' : meanGrossData,
                         'Mean Budget' : meanBudgetData})

# %%
meanData.head()
# Out:
#        Genre    Mean Gross   Mean Budget
# 0     Action  5.404332e+07  4.673630e+07
# 1  Adventure  8.814746e+07  7.063706e+07
# 2  Animation  8.369201e+07  5.766503e+07
# 3  Biography  2.169354e+07  1.519645e+07
# 4     Comedy  3.330247e+07  2.178094e+07

# %%
ax = sns.catplot(x= 'Mean Budget', y= 'Mean Gross', hue ='Genre', data = meanData)

# %% [markdown]
# - Okay not so much, maybe try something else:

# %%
dfGenreFin.head()
# Out:
#                     title studio  domestic_gross  foreign_gross    year  \
# 0                     '71  RAtt.       1300000.0       355000.0  2015.0
# 1  1,000 Times Good Night     FM         53900.0            0.0  2014.0
# 2     10 Cloverfield Lane   Par.      72100000.0     38100000.0  2016.0
# 3   10 Days in a Madhouse    NaN         14616.0            0.0     NaN
# 4                10 Years  Anch.        203000.0            0.0  2012.0
#
#    release_date  production_budget  worldwide_gross         original_title  \
# 0           NaN                0.0        1655000.0                    '71
# 1           NaN                0.0          53900.0  Tusen ganger god natt
# 2  Mar 11, 2016          5000000.0      108286422.0    10 Cloverfield Lane
# 3  Nov 11, 2015         12000000.0          14616.0  10 Days in a Madhouse
# 4           NaN                0.0         203000.0               10 Years
#
#    start_year  runtime_minutes  averagerating  numvotes   movie_id  \
# 0      2014.0             99.0            7.2   46103.0  tt2614684
# 1      2013.0            117.0            7.1    6848.0  tt2353767
# 2      2016.0            103.0            7.2  260383.0  tt1179933
# 3      2015.0            111.0            6.7    1114.0  tt3453052
# 4      2011.0            100.0            6.1   22484.0  tt1715873
#
#                   genresList
# 0  [Action, Drama, Thriller]
# 1               [Drama, War]
# 2   [Drama, Horror, Mystery]
# 3                    [Drama]
# 4   [Comedy, Drama, Romance]

# %%
dfGenreFinGrouped = dfGenreFin.groupby(['genresList'])[['domestic_gross', 'foreign_gross', 'worldwide_gross', 'production_budget']]

# %%
dfGenreFinGrouped

# %% [markdown]
# # Let's group by Genre individually

# %%
 def getGenreInfo(keyword):    
    allInfo = {}
    title = []
    genre = []
    domestic_gross = []
    foreign_gross = []
    worldwide_gross = []
    production_budget = []
    for i in dfGenreFin.index:
        
        if any(keyword in g for g in dfGenreFin['genresList'][i]):
            genre.append(keyword)
            title.append(dfGenreFin['title'][i])
            domestic_gross.append(dfGenreFin['domestic_gross'][i])
            foreign_gross.append(dfGenreFin['foreign_gross'][i])
            worldwide_gross.append(dfGenreFin['worldwide_gross'][i])
            production_budget.append(dfGenreFin['production_budget'][i])
        allInfo.update({'Title' : title,
                        'Genre' : genre,
                        'Domestic Gross' : domestic_gross,
                        'Foreign Gross' : foreign_gross,
                        'Worldwide Gross' : worldwide_gross,
                        'Production Budget' : production_budget})
    return allInfo

# %%
nextTestDF = pd.DataFrame(getGenreInfo('Action'))
nextTestDF
# Out:
#                                            Title   Genre  Domestic Gross  \
# 0                                            '71  Action       1300000.0
# 1                                      12 Rounds  Action      12234694.0
# 2                                      12 Strong  Action      45800000.0
# 3                                   13 Assassins  Action        803000.0
# 4                                      14 Blades  Action             0.0
# ..                                           ...     ...             ...
# 930                                  You're Next  Action      18500000.0
# 931  Young Detective Dee: Rise of the Sea Dragon  Action         87800.0
# 932                                      Z Storm  Action             0.0
# 933                                   Zombeavers  Action         14900.0
# 934                   xXx: Return of Xander Cage  Action      44898413.0
#
#      Foreign Gross  Worldwide Gross  Production Budget
# 0         355000.0        1655000.0                0.0
# 1        5071954.0       17306648.0         20000000.0
# 2       21600000.0       71118378.0         35000000.0
# 3       16800000.0       17603000.0                0.0
# 4        3800000.0        3800000.0                0.0
# ..             ...              ...                ...
# 930      8387177.0       26887177.0          1000000.0
# 931     72200000.0       72287800.0                0.0
# 932      2053330.0        2053330.0          7000000.0
# 933            0.0          14900.0                0.0
# 934    300134946.0      345033359.0         85000000.0
#
# [935 rows x 6 columns]

# %%
def getDataForGenres():
    thisDict = {}
    for i in genreList:
        thisDict.update(getGenreInfo(i))

# %%
for i in genreList:
        print(getGenreInfo(i))
# Out:
# {'Title': ["'71", '12 Rounds', '12 Strong', '13 Assassins', '14 Blades', '1911', '2 Guns', '21 Jump Street', '22 Bullets', '22 Jump Street', '3 Days to Kill', '30 Minutes or Less', '300: Rise of an Empire', '47 Ronin', '5 Days of War', '7 Days in Entebbe', 'A Gentleman', 'A Good Day to Die Hard', 'A Melody to Remember', 'A Taxi Driver', 'A Walk Among the Tombstones', 'ATM', 'Abduction', 'Abduction', 'Abduction', 'Abraham Lincoln: Vampire Hunter', 'Act of Valor', 'Action Jackson', 'Adam', 'Admiral', 'Adrift', 'After Earth', 'Agent Vinod', 'Agneepath', 'Air Strike', 'Akira', 'Alex Cross', 'Alita: Battle Angel', 'All Is Lost', 'All or Nothing', 'Allied', 'Along with the Gods: The Two Worlds', 'American Assassin', 'American Heist', 'American Hero', 'American Made', 'American Sniper', 'American Ultra', 'Anna', 'Anonymous', 'Ant-Man', 'Ant-Man and the Wasp', 'Aquaman', "Assassin's Creed", 'Assassins', 'Asura: The City of Madness', 'Atomic Blonde', 'Attack on Titan: Part 1', 'Attack the Block', 'Avengers: Age of Ultron', 'Avengers: Infinity War', 'Baaghi', 'Baaghi 2', 'Baahubali 2: The Conclusion', 'Baahubali: The Beginning', 'Baby Driver', 'Bad Company', 'Bait', 'Bajirao Mastani', 'Bajrangi Bhaijaan', 'Bang Bang', 'Barely Lethal', 'Batman v Superman: Dawn of Justice', 'Batman: The Killing Joke', 'Battleship', 'Baywatch', 'Bellflower', 'Ben-Hur', 'Ben-Hur', 'Beowulf', 'Besharam', 'Beyond Outrage', 'Big Fish', 'Big Game', 'Big Hero 6', 'Big Mommas: Like Father, Like Son', 'Bilal: A New Breed of Hero', "Billy Lynn's Long Halftime Walk", 'Birth of the Dragon', 'Black Death', 'Black November', 'Black Panther', 'Black and White', 'Black or White', 'Blackhat', 'Blackthorn', 'Blade of the Immortal', 'Blind', 'Blood Ties', 'Blood Ties', 'Bodyguard', 'Bodyguard', 'Bodyguard', 'Bol Bachchan', 'Bombay Velvet', 'Boomerang', 'Born to Fly: Elizabeth Streb vs. Gravity', 'Boruto: Naruto the Movie', 'Bound', 'Breaking In', 'Brick Mansions', 'Broken Horses', 'Brothers', 'Brothers', 'Brothers', 'Brothers', 'Brothers', 'Brothers', 'Brothers', 'Brothers', 'Buddies in India', 'Bullet to the Head', 'Bumblebee', 'Captain America: Civil War', 'Captain America: The First Avenger', 'Captain America: The Winter Soldier', 'Captain Marvel', 'Captain Underpants: The First Epic Movie', 'Captive', 'Captive', 'Cats & Dogs: The Revenge of Kitty Galore', 'Central Intelligence', 'Centurion', 'Chakravyuh', 'Chappie', "Charlie's Angels", 'Chennai Express', 'Choke', 'City of Angels', 'City of Gold', 'Clash of the Titans', 'Clash of the Titans', 'Cloud Atlas', 'Cold Pursuit', 'Collide', 'Collide', 'Colombiana', 'Commando', 'Commitment', 'Compadres', 'Conan the Barbarian', 'Conan the Barbarian', 'Confidential Assignment', 'Contagion', 'Contraband', 'Control', 'Cop Out', 'Cowboys & Aliens', 'Creature', 'Criminal', 'Criminal', 'Crossroads', 'Crossroads', 'Dabangg 2', 'Dancer', 'Dangal', 'Dangal', 'Dark Phoenix', 'Dark Places', 'Dark Tide', 'Dawn of the Planet of the Apes', 'Dead Man Down', 'Deadpool', 'Deadpool 2', 'Death Wish', 'Deepwater Horizon', 'Delhi Belly', 'Den of Thieves', 'Departure', 'Derailed', 'Destiny', 'Destroyer', 'Detective Chinatown 2', 'Detective K: Secret of the Lost Island', 'Detention of the Dead', 'Dhoom 3', 'Dilwale', 'Dishoom', 'Divergent', 'Doctor Strange', 'Don 2', 'Doomsday', 'Double Trouble', 'Dracula Untold', 'Dragon Ball Super: Broly', 'Dragon Ball Z: Battle of Gods', "Dragon Ball Z: Resurrection 'F'", 'Dragon Blade', 'Dragonfly', 'Dredd', 'Drive', 'Drive Angry', 'Drug War', 'Dum Maaro Dum', 'Dunkirk', 'Dylan Dog: Dead of Night', 'Edge of Tomorrow', 'Ek Tha Tiger', 'Ek Villain', 'Elite Squad: The Enemy Within', 'Elysium', 'Empire of Lust', 'End of Watch', "Ender's Game", 'Escape Plan', 'Evangelion: 3.0 You Can (Not) Redo', 'Everest', 'Exodus: Gods and Kings', 'Explosion', 'Extraction', 'Extraction', 'Extraction', 'Extraordinary Mission', 'Eyes Wide Open', 'Fabricated City', 'Falcon Rising', 'Fan', 'Fantastic Four', 'Fantastic Four', 'Fast & Furio ...
Lantern', 'Guardians of the Galaxy', 'Guardians of the Galaxy Vol. 2', "Gulliver's Travels", 'Gun Shy', 'Happy Feet Two', 'Hardcore Henry', 'Hellboy', 'Hellboy', 'Henry V', 'Hercules', 'Hercules', 'Himmatwala', 'Hitman: Agent 47', 'Holmes & Watson', 'Home', 'Home', 'Hop', 'Hostiles', 'Hotel Transylvania 3: Summer Vacation', 'How to Train Your Dragon', 'How to Train Your Dragon 2', 'How to Train Your Dragon: The Hidden World', 'Hugo', 'Hunt for the Wilderpeople', 'I Am Number Four', 'Ice Age: Collision Course', 'Ice Age: Continental Drift', 'Identity Thief', 'In the Heart of the Sea', 'Inception', 'Incredibles 2', 'Independence Day: Resurgence', 'Inferno', 'Inside Out', 'Interstellar', 'Into the Storm', 'Into the Woods', 'Iron Man 2', 'Iron Man 3', 'Ironclad', 'Jack and the Cuckoo-Clock Heart', 'Jack the Giant Slayer', 'Jem and the Holograms', 'John Carter', 'Johnny English Reborn', 'Johnny English Strikes Again', 'Journey 2: The Mysterious Island', 'Journey to the West', 'Journey to the West: The Demons S ...
# {'Title': ['A Letter to Momo', 'A Monster Calls', 'A Silent Voice', 'A.C.O.R.N.S.: Operation Crackdown', 'Alpha and Omega', 'Alvin and the Chipmunks: Chipwrecked', 'Alvin and the Chipmunks: The Road Chip', 'Anomalisa', 'April and the Extraordinary World', 'Arthur Christmas', 'As Above, So Below', 'Back to the Jurassic', 'Barbara', 'Batman: The Killing Joke', 'Big Hero 6', 'Bilal: A New Breed of Hero', 'Black Butler: Book of the Atlantic', 'Boruto: Naruto the Movie', 'Brave', 'Captain Underpants: The First Epic Movie', 'Capture the Flag', 'Cars 2', 'Cars 3', 'Chico & Rita', 'Christopher Robin', 'Cloudy with a Chance of Meatballs 2', 'Coco', 'Death of a Superhero', 'Despicable Me', 'Despicable Me 2', 'Despicable Me 3', 'Dinosaur', 'Dinosaur', 'Dragon Ball Super: Broly', 'Dragon Ball Z: Battle of Gods', "Dragon Ball Z: Resurrection 'F'", 'Early Man', 'Eden', 'Epic', 'Ernest & Celestine', 'Evangelion: 3.0 You Can (Not) Redo', "Fate/Stay Night: Heaven's Feel - I. Presage Flower", "Father's Day", 'Ferdinand', 'Finding Dory', 'Foodfight!', 'Frankenweenie', 'Free Birds', 'From Up on Poppy Hill', 'Frozen', 'Ghost in the Shell: The New Movie', 'Gladiators of Rome', 'Happy Feet Two', 'Home', 'Home', 'Home', 'Home', 'Hoodwinked Too! Hood vs. Evil', 'Hop', 'Hotel Transylvania', 'Hotel Transylvania 2', 'Hotel Transylvania 3: Summer Vacation', 'How to Train Your Dragon', 'How to Train Your Dragon 2', 'How to Train Your Dragon: The Hidden World', 'Ice Age: Collision Course', 'Ice Age: Continental Drift', 'In This Corner of the World', 'Incredibles 2', 'Inside Out', 'Jack and the Cuckoo-Clock Heart', 'Jungle Shuffle', 'Khumba', 'Kochadaiiyaan', 'Kubo and the Two Strings', 'Kung Fu Panda 2', 'Kung Fu Panda 3', 'L.O.R.D: Legend of Ravaging Dynasties', 'Leap!', "Legend of the Guardians: The Owls of Ga'Hoole", "Legends of Oz: Dorothy's Return", 'Lost and Found', 'Love Live! The School Idol Movie', 'Loving Vincent', 'Lucy', "Madagascar 3: Europe's Most Wanted", 'Mars Needs Moms', "Mary and the Witch's Flower", 'Megamind', 'Minions', 'Mirai', 'Miss Hokusai', 'Moana', 'Monster Family', 'Monsters University', 'Mr. Peabody & Sherman', 'My Hero Academia: Two Heroes', 'My Life as a Zucchini', 'My Little Pony: The Movie', 'No Strings Attached', 'Noah', 'Norm of the North', 'One Piece Film: Gold', 'ParaNorman', 'Penguins of Madagascar', 'Peter Rabbit', 'Phantom Boy', 'Pinocchio', 'Pinocchio', 'Pinocchio', 'Pinocchio', 'Planes', 'Planes: Fire & Rescue', 'Postman Pat: The Movie', 'Puss in Boots', 'Ralph Breaks the Internet', 'Rango', 'Ratchet & Clank', 'Rio', 'Rio 2', 'Rise of the Guardians', 'Rock Dog', 'Sahara', 'Sausage Party', 'Sgt. Stubby: An American Hero', 'Shaun the Sheep Movie', 'Sherlock Gnomes', 'Shrek Forever After', 'Sing', 'Smallfoot', 'Smurfs: The Lost Village', 'Snow White and the Seven Dwarfs', 'Song of the Sea', 'Space Pirate Captain Harlock', 'Storks', 'Strange Magic', 'Sword Art Online: The Movie - Ordinal Scale', 'Tag', 'Tales of the Night', 'Tangled', 'Tarzan', 'Tehran Taboo', 'The Addams Family', 'The Adventures of Tintin', 'The Angry Birds Movie', 'The Apostle', 'The Apostle', 'The Book of Life', 'The Boss Baby', 'The Boxtrolls', 'The Boy and the Beast', 'The Breadwinner', 'The Cave', 'The Congress', 'The Croods', 'The Emoji Movie', 'The Gift', 'The Gift', 'The Girl Without Hands', 'The Good Dinosaur', 'The Greatest Miracle', 'The Guardian', 'The Hero of Color City', 'The House', 'The Illusionist', 'The Jungle Book', 'The Jungle Book', 'The Lego Batman Movie', 'The Lego Movie', 'The Lego Ninjago Movie', 'The Lion King', 'The Little Prince', 'The Nut Job', 'The Nut Job 2: Nutty by Nature', 'The Peanuts Movie', 'The Pirates! Band of Misfits', "The Rabbi's Cat", 'The Red Turtle', 'The Secret Life of Pets', 'The Secret Life of Pets 2', 'The Secret World of Arrietty', 'The Smurfs', 'The Smurfs 2', 'The Son of Bigfoot', 'The SpongeBob Movie: Sponge Out of Water', 'The Star', 'The Tale of The Princess Kaguya', 'The Wind Rises', 'Thunder and  ...
# {'Title': ['12 Years a Slave', '127 Hours', '42', '6 Below: Miracle on the Mountain', 'A Dangerous Method', 'A Man for All Seasons', 'A Private War', 'A Quiet Passion', 'A Royal Affair', 'A Street Cat Named Bob', 'A Tale of Love and Darkness', 'A United Kingdom', 'A Walk in the Woods', 'Admiral', 'Adrift', 'Advanced Style', 'Afterimage', 'Against the Sun', 'Alive', 'All Eyez on Me', 'All or Nothing', 'All or Nothing', 'All the Money in the World', 'American Made', 'American Sniper', 'Amy', 'Anchor Baby', 'Anna', 'Anna', 'Annie', 'Antarctica: A Year on Ice', 'Anthropoid', 'Antonio Lopez 1970: Sex Fashion & Disco', 'Argo',
Killing Joke', 'Baywatch', 'Beast', 'Beast', 'Beauty and the Dogs', 'Benji', 'Bernie', 'Better Watch Out', 'Beyond Outrage', 'Big Eyes', 'Big Game', 'Big Mommas: Like Father, Like Son', 'BlacKkKlansman', 'Black Mass', 'Black November', 'Blackhat', 'Blind', 'Blind', 'Blindspotting', 'Blood Ties', 'Blue Ruin', 'Bombay Velvet', 'Breaking In', 'Breathless', 'Brick Mansions', 'Brighton Rock', 'Broken City', 'Broken Horses', 'Bullet to the Head', 'Bullhead', 'Burke and Hare', 'Ca$h', 'Ca$h', 'Can You Ever Forgive Me?', 'Captive', 'Carancho', 'Casino Jack', 'Central Intelligence', 'Chappie', 'Cheap Thrills', 'Chi-Raq', 'Chicago', 'Chico & Rita', 'Child 44', 'Closed Circuit', 'Closer to the Moon', 'Cock and Bull', 'Cold Pursuit', 'Collide', 'Compadres', 'Compliance', 'Contraband', 'Control', 'Control', 'Control', 'Conviction', 'Cop Car', 'Cop Out', 'Creature', 'Creed', 'Criminal', 'Criminal', 'Criminal Activities', 'Crossroads', 'Cyrus', 'Dark Blue', 'Date Night', 'Daylight', 'Dead Man Down', 'Deadfall', 'Death Wish', 'Delhi Belly', 'Den of Thieves', 'Derailed', 'Destroyer', 'Detective K: Secret of the Living Dead', 'Detroit', 'Dheepan', 'Difret', 'Diner', 'Dirty Work', 'Dom Hemingway', 'Domino', 'Don 2', "Don't Breathe", 'Dope', 'Double Dhamaal', 'Dragonfly', 'Dreamcatcher', 'Dredd', 'Drive', 'Drive', 'Drug War', 'Dum Maaro Dum', 'Duma', 'Dylan Dog: Dead of Night', 'Eastern Boys', 'Eden', 'Eden', 'Edge of Darkness', 'Ek Villain', 'Elena', 'Elite Squad: The Enemy Within', 'Elle', 'End of Watch', 'Escape Plan', 'Escobar: Paradise Lost', 'Every Secret Thing', 'Exit Through the Gift Shop', 'Extraction', 'Extraction', 'Extraordinary Mission', 'Fabricated City', 'Fast & Furious 6', 'Fast Five', 'Faster', 'Filth', 'Firestorm', 'Flypaper', 'Focus', 'Four Lions', 'Free Fire', 'Freedom', 'Freedom', 'From Paris with Love', 'Frontera', 'Furious 7', 'Game Night', 'Gangster Squad', 'Get Hard', 'Getaway', 'Ghanchakkar', 'Gifted', 'Glass', 'God Bless America', "God's Pocket", 'Going in Style', 'Good Time', 'Gotti', 'Grace', 'Grace', 'Gracie', 'Graduation', 'Gringo', 'Haider', 'Happy End', 'Headhunters', 'Heist', 'Heist', 'Heist', 'Heist', 'Heli', 'Hell or High Water', "Henry's Crime", 'Hero', 'Hesher', 'Hide and Seek', 'Hitman: Agent 47', 'Holly', 'Holmes & Watson', 'Holy Rollers', 'Hoodwinked Too! Hood vs. Evil', 'Horns', 'Horrible Bosses', 'Horrible Bosses 2', 'Hostel', 'Hot Pursuit', 'I Am Wrath', 'I Saw the Devil', 'Ice Age', 'Identity', 'Identity Thief', 'In Secret', 'In Time', 'Inferno', 'Inherent Vice', 'Inside Job', 'Inside Out', 'Into the Abyss', 'Intruders', 'J. Edgar', 'Jack', 'Jack Reacher', 'Jackpot', 'Jade', 'Jigsaw', 'Joe', 'John Wick', 'Joker', 'Joker', 'Kabali', 'Keanu', 'Khatta Meetha', 'Kick', 'Kick-Ass 2', 'Kidnap', 'Kill List', 'Kill Me Three Times', 'Kill the Irishman', 'Kill the Irishman', 'Kill the Messenger', 'Killer Elite', 'Killer Joe', 'Killers', 'Killing Them Softly', 'Last Man Standing', 'Lawless', 'Legend', 'Legend', "Let's Be Cops", 'Life of Crime', 'Lila & Eve', 'Live by Night', 'Logan Lucky', 'London Boulevard', 'London Fields', 'Looper', 'Love Crime', 'Loving Pablo', 'Loving Vincent', 'Lowriders', 'Luck-Key', 'Machete', 'Machete Kills', 'Mac ...
# {'Title': ['20 Feet from Stardom', '20,000 Days on Earth', '3', '50/50', '8: The Mormon Proposition', 'A Beautiful Planet', 'A Man for All Seasons', 'A Quiet Place', 'A Separation', 'A Star is Born', 'Above and Beyond', 'Above and Beyond', 'Addicted', 'Advanced Style', 'African Cats', 'Ai Weiwei: Never Sorry', 'Alice in Wonderland', 'All You Need Is Love', 'All or Nothing', 'All or Nothing', 'American Dreamz', 'Amy', 'An Inconvenient Sequel: Truth to Power', 'Anchor Baby', 'Anna', 'Annie', 'Annie', 'Another Year', 'Antarctica: A Year on Ice', 'Antonio Lopez 1970: Sex Fashion & Disco', 'Any Given Sunday', 'Archipelago', 'Argentina', 'Armadillo', 'Arrival', 'As Above, So Below', 'As Above, So Below', 'Aurora', 'Author: The JT LeRoy Story', 'Awake: The Life of Yogananda', 'Babies', 'Ballerina', 'Bambi', 'Barbara', 'Barbecue', 'Bastards', 'Bears', 'Becoming Traviata', 'Before We Go', "Being Elmo: A Puppeteer's Journey", 'Believe', 'Beloved', 'Bending the Arc', 'Benji', 'Beyond Borders', 'Beyond the Sea', 'Big', 'Big Eyes', 'Birth', 'Black Hawk Down', 'Blood Ties', 'Blood Ties', 'Bobby', 'Bones', 'Book Club', 'Born in China', 'Born to Fly: Elizabeth Streb vs. Gravity', 'Bound', 'Brainstorm', 'Breathless', 'Brothers', 'Brothers', 'Brothers', 'Brothers', 'Brothers', 'Brothers', 'Buck', 'Buena Vista Social Club: Adios', 'Bully', 'Buried', 'Burn', 'Burn the Stage: The Movie', 'Burning', 'Butterfly Girl', 'Capital', 'Capital', 'Cargo', 'Cartel Land', 'Casino Jack and the United States of Money', 'Casting By', 'Catfish', 'Cave of Forgotten Dreams', 'Celine: Through the Eyes of the World', 'Ceremony', 'Chasing Ice', 'Chicago', 'Chimpanzee', 'Chloe', 'Circle', 'Citizenfour', 'City of Ghosts', 'City of Gold', 'Client 9: The Rise and Fall of Eliot Spitzer', 'Colette', 'Coming Home', 'Coming Home', 'Coming Home', 'Coming Home', 'Concussion', 'Contact', 'Contact', 'Control', 'Counting', 'Creature', 'Crossroads', 'Crossroads', 'Cube', 'Dancer', 'Dark Horse', 'David Lynch: The Art Life', 'Deceptive Practice: The Mysteries and Mentors of Ricky Jay', 'Demonic', 'Denial', 'Diana', 'Diana Vreeland: The Eye Has to Travel', 'Dinosaur', 'Dior and I', 'Do I Sound Gay?', "Don't Breathe", 'Down to Earth', 'Down to Earth', 'Dragonslayer', 'Dreamcatcher', 'Dreams of a Life', 'Drive', 'Driven', 'Driven', 'Duma', 'Earth', 'Earth', 'Earth', 'Earth: One Amazing Day', 'El Bulli: Cooking in Progress', 'Elena', 'Elizabeth', 'Elle', 'Emily', 'End of Days', 'Exit Through the Gift Shop', 'Exit Wounds', 'Exodus', 'Exodus', 'Exodus', 'Eyes Wide Open', 'Faces Places', 'Fahrenheit 11/9', 'Fair Game', 'Faith Connections', 'Fame', 'Father Figures', 'Fatima', 'Fed Up', 'Final Destination', 'Finding Vivian Maier', 'Fire at Sea', 'Firestarter', 'Firestorm', 'First Man', 'First Position', 'Flood', 'Food Chains', 'Footnote', 'For No Good Reason', 'Forget Me Not', 'Forget Me Not', 'Forget Me Not', 'Fortress', 'Freakonomics', 'Free Men', 'Free Solo', 'Freedom', 'Freedom', 'Freedom', 'Freedom', 'Fuel', 'GasLand', 'Generation Iron', 'Gerhard Richter Painting', 'Ghost Town', 'Gifted', 'Gladiator', 'Gladiator', 'Glee: The 3D Concert Movie', 'Gone', 'Gone', 'Gone', 'Good', 'Graduation', 'Happiness', 'Happiness', 'Happy End', 'Happy Valley', 'Harry & Snowman', 'He Named Me Malala', 'Head Over Heels', 'Heart of a Dog', "Heaven's Gate", 'Heavy Metal', 'Hell and Back Again', 'Heroes', 'Hit So Hard', 'Hitchcock/Truffaut', 'Hockney', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home', 'Home Movies', 'Home Movies', 'Hoodwinked', 'Hugo', 'Human Flow', 'Hybrid', 'I Am Eleven', 'I Am Not Your Negro', 'I Want Your Money', 'In Between', 'In Between', 'In the Basement', 'Indivisible', 'Inferno', 'Ingrid Bergman: In Her Own Words', 'Inside Job', 'Inside Out', 'Inside Out', 'Into the Abyss', 'Into the Storm', 'Into the White', 'Iris', 'Jackass 3D', 'Jackpot', 'J ...
# {'Title': ["'71", '1,000 Times Good Night', '10 Cloverfield Lane', '10 Days in a Madhouse', '10 Years', '1001 Grams', '102 Not Out', '12 Rounds', '12 Strong', '12 Years a Slave', '127 Hours', '13 Assassins', '17 Girls', '1911', '2 Days in New York', '2 States', '20,000 Days on Earth', '20th Century Women', '22 Bullets', '23 Blast', '28 Hotel Rooms', '3', '3', '3', '3', '3 Backyards', '3 Days to Kill', '3 Generations', '360', '42', '45 Years', '47 Meters Down', '47 Ronin', '5 Days of War', '5 Flights Up', '5 to 7', '50 to 1', '50/50', '6 Below: Miracle on the Mountain', '7 Boxes', '7 Days in Entebbe', '90 Minutes in Heaven', '99 Homes', 'A Beautiful Life', 'A Better Life', 'A Better Life', 'A Bigger Splash', 'A Bottle in the Gaza Sea', 'A Brilliant Young Mind', 'A Ciambra', 'A Coffee in Berlin', 'A Cure for Wellness', 'A Dangerous Method', "A Dog's
ental Guidance', 'Percy Jackson & the Olympians: The Lightning Thief', 'Percy Jackson: Sea of Monsters', 'Pinocchio', 'Pinocchio', 'Pinocchio', 'Pinocchio', 'Postman Pat: The Movie', 'Prom', 'Quarantine', 'Ramona and Beezus', 'Real Steel', 'Redemption', 'Reuniting the Rubins', 'Secretariat', 'Sgt. Stubby: An American Hero', 'Show Dogs', 'Shutter', 'Sing', 'Snow White and the Seven Dwarfs', 'Soul Surfer', 'Summer 1993', 'Sunday', 'The Addams Family', 'The Adventures of Huck Finn', 'The BFG', 'The Book of Life', 'The Breadwinner', 'The Calling', 'The Christmas Candle', 'The Chronicles of Narnia: The Voyage of the Dawn Treader', 'The Concert', 'The Guardians', 'The Hero of Color City', 'The Hobbit: An Unexpected Journey', 'The House That Jack Built', 'The Journey', 'The Journey', 'The Jungle Book', 'The Jungle Book', 'The Karate Kid', 'The Karate Kid', 'The Kid', 'The Kid Who Would Be King', 'The Last Airbender', 'The Last Shot', 'The Lost Medallion: The Adventures of Billy Stone', 'The Mask', 'The Messenger', 'The Muppets', 'The Nutcracker and the Four Realms', 'The Nutcracker in 3D', 'The Odd Life of Timothy Green', 'The Other Side', 'The Perfect Match', 'The Pledge', 'The Resurrection of Gavin Stone', 'The Return', 'The Return', 'The Rock', 'The Secret World of Arrietty', "The Sorcerer's Apprentice", 'The Spy Next Door', 'The Square', 'The Square', 'The Strangers', 'The Three Stooges', 'The Tree', 'The Visitor', 'The Workshop', 'Thelma', 'Titanic', 'Tomorrowland', 'Tooth Fairy', 'Triangle', 'Twelve', 'Under the Rainbow', 'Underdogs', 'Underdogs', 'Unfinished Business', 'Upside Down', 'Venus', 'Virus', 'We Are Family', 'We A ...
# {'Title': ['300: Rise of an Empire', 'A Cure for Wellness', 'A Ghost Story', 'A Haunted House', 'A Haunted House 2', 'A Little Bit of Heaven', 'A Monster Calls', 'A Pigeon Sat on a Branch Reflecting on Existence', 'A Werewolf Boy', 'A Wrinkle in Time', 'About Time', 'Abracadabra', 'Abracadabra', 'Abraham Lincoln: Vampire Hunter', 'Aladdin', 'Aladdin', 'Alice Through the Looking Glass', 'Alice in Wonderland', 'Alice in Wonderland', 'Along with the Gods: The Two Worlds', 'Alpha', 'Anastasia', 'Animal Kingdom', 'Aquaman', 'Batman v Superman: Dawn of Justice', 'Beastly', 'Beasts of the Southern Wild', 'Beautiful Creatures', 'Beauty and the Beast', 'Beauty and the Beast', 'Beauty and the Beast', 'Beauty and the Beast', 'Beauty and the Beast', 'Beauty and the Beast', 'Before I Fall', 'Beowulf', 'Bird People', 'Blade of the Immortal', 'Blancanieves', 'Branded', 'Byzantium', 'Cemetery of Splendor', 'Charlie St. Cloud', 'Cinderella', 'Cinderella', 'Cinderella', 'Cinderella', 'Cinderella', 'Cinderella', 'Cirque du Soleil: Worlds Away', 'Clash of the Titans', 'Clash of the Titans', 'Closet Monster', 'Clown', 'Colossal', 'Conan the Barbarian', 'Conan the Barbarian', 'Cosmopolis', 'Crimson Peak', 'Dark Shadows', 'Do You Believe?', 'Doctor Strange', "Don't
# {'Title': ['12 Strong', '12 Years a Slave', '14 Blades', '7 Days in Entebbe', 'A Royal Affair', 'A Tale of Love and Darkness', 'A Taxi Driver', 'Above and Beyond', 'Afterimage', 'All or Nothing', 'Alone in Berlin', 'Anthropoid', 'Bajirao Mastani', 'Beginning of the Great Revival', 'Bel Ami', 'Beloved Sisters', 'Beneath Hill 60', 'Bridge of Spies', 'Burke and Hare', 'Capital', 'Cave of Forgotten Dreams', 'Chappaquiddick', 'Child 44', 'Churchill', 'Cinco de Mayo, La Batalla', 'Colette', 'Colette', 'Contact', 'Coriolanus', 'Darkest Hour', 'Deepwater Horizon', 'Detroit', 'Dunkirk', 'Edmond', 'Elvis & Nixon', 'Emperor', 'Enough', 'Escobar: Paradise Lost', 'Even the Rain', 'Experimenter', 'Eyes Wide Open', 'First Man', 'For Greater Glory: The True Story of Cristiada', 'For No Good Reason', 'Fort McCoy', 'Francofonia', 'Frantz', 'Free Men', 'Ghost Town', 'Gold', 'Gold', 'Hacksaw Ridge', 'Hell and Back Again', 'Heneral Luna', 'Hidden Figures', 'Home', 'Home', 'Home', 'Home', 'Hostage', 'In This Corner of the World', 'Inside Out', 'Iris', 'Iris', 'Jackie', 'Jane Eyre', "Jimmy's Hall", 'Kingdom Come', 'Kon-Tiki', 'LBJ', 'Labyrinth of Lies', 'Land of Mine', 'Legend of the Fist: The Return of Chen Zhen', 'Life During Wartime', 'Lincoln', 'Lincoln', 'Little Boy', 'Lore', 'Mandela: Long Walk to Freedom', 'Mark Felt: The Man Who Brought Down the White House', 'Mary Queen of Scots', 'Mary Queen of Scots', 'Mary Shelley', 'Memories of the Sword', 'Miral', 'Monsters', 'Mr. Turner', 'Neruda', 'Nerve', 'Never Look Away', 'November', 'Of Gods and Men', 'Oranges and Sunshine', 'Padmaavat', 'Parkland', 'Phantom', 'Plot for Peace', 'Point Blank', 'Race', 'Red', 'Red Army', 'Red Dog', 'Red Dog', 'Red Obsession', 'Renoir', 'Return of the Hero', 'Robin Hood', 'Robin Hood', 'Selma', 'Seondal: The Man Who Sells the River', 'Serena', 'Silence', 'Snow Flower and the Secret Fan', 'Son of God', 'Southside with You', 'Stonewall', 'Straight Outta Compton', 'Suffragette', 'Teeth', 'Testament of Youth', 'Texas Killing Fields', 'The 33', 'The Assassin', 'The Battleship Island', 'The Bay', 'The Best of Enemies', 'The Birth of a Nation', 'The Birth of a Nation', 'The Captain', 'The Circle', 'The Connection', 'The Conspirator', 'The Cut', 'The Death of Stalin', 'The Escape', 'The Face Reader', 'The Favourite', 'The Fencer', 'The Finest Hours', 'The Flowers of War', 'The Forest', 'The Fortress', 'The Founder', 'The Front Runner', 'The Gatekeepers', 'The German Doctor', 'The Impossible', 'The Innocents', 'The Invisible Woman', "The King's Choice", "The King's Speech", 'The Lady', 'The Last King', 'The Look of Silence', 'The Master', 'The Mill and the Cross', 'The Monuments Men', 'The Negotiation', 'The Post', 'The Princess of Montpensier', 'The Promise', 'The Return', 'The Salt of the Earth', 'The Scarlet Letter', 'The Silence', 'The Square', 'The Square', 'The Stanford Prison Experiment', 'The Water Diviner', 'The Way Back', 'The Young
# {'Title': ["'71", '11-11-11', '13 Sins', '14 Blades', '2:22', '3', '3 Days to Kill', '31', '360', '6 Souls', 'A Bigger Splash', 'A Good Day to Die Hard', 'A Hijacking', 'A Lonely Place to Die', 'A Monster with a Thousand Heads', 'A Most Violent Year', 'A Most Wanted Man', 'A Separation', 'ATM', 'Abduction', 'Abduction', 'Acrimony', 'Action Jackson', 'Adam', 'Addicted', 'Agent Vinod', 'Alien: Covenant', 'Alive', 'All or Nothing', 'All or Nothing', 'American Assassin', 'Amityville: The Awakening', 'Anchor Baby', 'Andhadhun', 'Anesthesia', 'Anna', 'Anna', 'Annabelle', 'Annabelle: Creation', 'Anonymous', 'Anthropoid', 'Antiviral', 'Anywhere But Here', 'Apartment 143', 'Arbitrage', 'Area 51', 'Argo', 'As Good as Dead', 'Assassins', 'At Any Price', 'Atomic Blonde', 'Aurora', 'Baaghi', 'Baaghi 2', 'Bad Company', 'Bad Samaritan', 'Bait', 'Bait', 'Bait', 'Banshee Chapter', 'Beast', 'Beast', 'Beauty and the Dogs', 'Beirut', 'Berberian Sound Studio', 'Bethlehem', 'Beyond the Black Rainbow', 'Beyond the Reach', "Billy Lynn's Long Halftime Walk", 'Black Sea', 'Black Swan', 'Black or White', 'Blackhat', 'Blackway', 'Blair Witch', 'Blue Ruin', 'Bluebeard', 'Bluebeard', 'Bodom', 'Bodyguard', 'Boomerang', 'Bound', 'Braid', 'Brainstorm', 'Branded', 'Breakdown', 'Breakdown', 'Breathless', 'Bridge of Spies', 'Brighton Rock', 'Broken City', 'Brother', 'Brother', 'Bug', 'Bullet to the Head', 'Buried', 'Buried', 'Burn', 'Ca$h', 'Ca$h', 'Cake', 'Canopy', 'Captain Phillips', 'Captive', 'Captive', 'Captive State', 'Chakravyuh', 'Chappaquiddick', 'Chernobyl Diaries', 'Chronicle', 'Circle', 'Citizenfour', 'Collide', 'Colombiana', 'Colonia', 'Commando', 'Conspiracy Theory', 'Contagion', 'Cop Car', 'Coriolanus', 'Cowboys & Aliens', 'Crash', 'Crash', 'Criminal Activities', "Daddy's Home", 'Dark Skies', 'Dawn of the Crescent Moon', 'Daylight', 'Daylight', 'Deadfall', 'Deliver Us from Evil', 'Demonic', 'Desierto', 'Devil', "Devil's Due", 'Dhoom 3', 'Disconnect', 'Disorder', 'Domino', 'Don 2', "Don't Be Afraid of the Dark", "Don't Breathe", 'Double Lover', 'Dragonfly', 'Dream House', 'Drive Angry', 'Driven', 'Driven', 'Duplicity', 'Dying of the Light', 'Eden', 'Ek Tha Tiger', 'Ek Thi Daayan', 'Elektra', 'Elena', 'Elizabeth', 'Elle', 'Emma', 'Enemy', 'Equilibrium', 'Evil Dead', 'Exeter', 'Explosion', 'Extraction', 'Extraction', 'Eye in the Sky', 'Eyes Wide Open', 'Fair Game', 'Fan', 'Fast & Furious 6', 'Fast Five', 'Fifty Shades Freed', 'Fifty Shades of Grey', 'Firestorm', 'First Reformed', 'Flight', 'Flipped', 'Flowers', 'Force', 'Frankenstein', 'Freedom', 'Freedom', 'Frenzy', 'Frequency', 'Friend Request', 'Friend Request', 'From Paris with Love', 'Frontera', 'Frontera', 'Furious 7', 'Gamer', 'Genius', 'Gentleman', 'Geostorm', 'Get Out', 'Getaway', 'Getaway', 'Ghanchakkar', 'Ghost', 'Ghost Rider: Spirit of Vengeance', 'Gifted', 'Gladiator', 'Glass', 'Glass', 'Gold', 'Golden Slumber', 'Golden Slumber', 'Gone', 'Gone', 'Gone Girl', 'Good Kill', 'Good Time', 'Goodnight Mommy', 'Graduation Day', 'Gravity', 'Green Room', 'Green Zone', 'Halloween', 'Halloween', 'Halloween', 'Hanna', 'Happy Death Day', 'Haywire', 'Headhunters', 'Heist', 'Heist', 'Hero', 'Hide and Seek', 'Hide and Seek', 'Higher Power', 'Holly', 'Home', 'Home', 'Home', 'Home', 'Homefront', 'Hostage', 'Hostiles', 'House at the End of the Street', 'Hungry Hearts', 'Hunter Killer', 'Hybrid', 'Hysteria', 'Hysteria', 'I Spit on Your Grave', 'I Spit on Your Grave 2', 'I Still See You', "I'm Still Here", 'In Bloom', 'In Darkness', 'In Secret', 'In the House', 'In the Shadow of the Moon', 'Incarnate', 'Inferno', 'Inhale', 'Insidious', 'Insidious: The Last Key', 'Into the Woods', 'Intruders', 'Intruders', 'Intruders', 'Intruders', 'Iris', "Ismael's Ghosts", 'It', 'Jack Reacher', 'Jack Reacher: Never Go Back', 'Jack Ryan: Shadow Recruit', 'Jackpot', 'Jason Bourne', 'Jessabelle', 'John Wick', 'Joker', 'Joker', 'Joker', 'Julia', 'Karthik Calling Karthik', 'Kick', 'Kidnap', 'Kidnap', 'Killer Elite', 'Killer Joe', ...
# {'Title': ['1,000 Times Good Night', '300: Rise of an Empire', '5 Days of War', 'A Melody to Remember', 'A Perfect Day', 'A Private War', 'A War', 'All or Nothing', 'Alone in Berlin', 'Amigo', 'Armadillo', 'Beneath Hill 60', 'Bethlehem', 'Bitter Harvest', 'Brothers', 'Brothers', 'Camp X-Ray', 'Caterpillar', 'Cinco de Mayo, La Batalla', 'City of Ghosts', 'Come What May', 'Coriolanus', 'Coriolanus', 'Crossroads', 'Cursed', 'Dear John', 'Diplomacy', 'Emperor', 'Entrapment', 'Exit Wounds', 'Exodus', 'Eye in the Sky', 'Far from Men', 'For Greater Glory: The True Story of Cristiada', 'Fort McCoy', 'Fury', 'Good Kill', 'Home', 'Home', 'In Darkness', 'In the Land of Blood and Honey', 'Incendies', 'Indivisible', 'Journey to the West', 'Land of Mine', 'Last Flag Flying', 'Little Boy', 'Live and Let Die', 'Mausam', 'Mr. Pip', "No Man's Land", "No Man's Land", 'Northern Limit Line', 'Ode to My Father', 'Outbreak', 'Railroad Tigers', 'Red Sky', 'Restrepo', 'Rock the Kasbah', "Sarah's Key", 'Silence', 'Sleepless', 'Son of Saul', 'Tangerines', 'Thank You for Your Service', 'The Art of War', 'The Book Thief', 'The Box', 'The Captain', 'The Catcher Was a Spy', 'The Gatekeepers', 'The Guardians', 'The History of Love', 'The Messenger', 'The Midwife', 'The Negotiation', 'The Notebook', 'The Patience Stone', 'The Queen', 'The Road', 'The Void', 'The Warring States', 'The Water Diviner', 'There Be Dragons', 'They Shall Not Grow Old', 'Tubelight', 'War Horse', 'War Witch', 'Wolf', 'Youth'], 'Genre': ['War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War', 'War',
# {'Title': ['A Million Ways to Die in the West', 'Blackthorn', 'Branded', 'Casa de mi Padre', 'Destiny', 'Django Unchained', 'Far from Men', 'Frontera', 'Gold', 'Hostiles', 'Jane Got a Gun', 'Jauja', 'Let the Bullets Fly', "Meek's Cutoff", "No Man's Land", 'Red Hill', 'Saving Private Perez', 'Slow West', 'Steel', 'The Divide', 'The Forgotten', 'The Gunman', 'The Homesman', 'The Keeping Room', 'The Kid', 'The Lone Ranger', 'The Magnificent Seven', 'The Return', 'The Rider', 'The Salvation', "The Warrior's Way", 'Trespass', 'True Grit', 'Wild Things', 'Witness'], 'Genre': ['Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western', 'Western'], 'Domestic Gross': [43100000.0, 201000.0, 354000.0, 5909483.0, 0.0, 162800000.0, 5300.0, 59696.0, 7200000.0, 29800000.0, 1500000.0, 60200.0, 63000.0, 978000.0, 1067481.0, 21100.0, 1400000.0, 229000.0, 1686429.0, 18000.0, 66711892.0, 10700000.0, 2400000.0, 27200.0, 69688384.0, 89300000.0, 93432655.0, 501752.0, 2400000.0, 44900.0, 5700000.0, 16816.0, 171200000.0, 29795299.0, 65532576.0], 'Foreign Gross': [44100000.0, 423000.0, 3400000.0, 2537469.0, 450.0, 262600000.0, 0.0, 0.0, 7700000.0, 0.0, 2271345.0, 0.0, 104300000.0, 891928.0, 1616726.0, 300000.0, 7900000.0, 0.0, 0.0, 138362.0, 50500000.0, 13500000.0, 5817571.0, 0.0, 0.0, 171200000.0, 69092501.0, 5452134.0, 0.0, 0.0, 5400000.0, 769716.0, 81000000.0, 25781400.0, 0.0], 'Worldwide Gross': [87200000.0, 1217307.0, 3754000.0, 8446952.0, 450.0, 449948323.0, 5300.0, 59696.0, 14900000.0, 29800000.0, 3771345.0, 60200.0, 104363000.0, 1869928.0, 2684207.0, 321100.0, 9300000.0, 229000.0, 1686429.0, 156362.0, 117211892.0, 18594227.0, 8217571.0, 27200.0, 69688384.0, 260002115.0, 162525156.0, 5953886.0, 2400000.0, 44900.0, 8514325.0, 786532.0, 252276928.0, 55576699.0, 65532576.0], 'Production Budget': [0.0, 4500000.0, 0.0, 6000000.0, 750000.0, 100000000.0, 0.0, 2300000.0, 0.0, 0.0, 25000000.0, 0.0, 0.0, 2000000.0, 1000000.0, 0.0, 0.0, 0.0, 16000000.0, 3000000.0, 50000000.0, 40000000.0, 16000000.0, 0.0, 65000000.0, 275000000.0, 90000000.0, 15000000.0, 0.0, 0.0, 42000000.0, 35000000.0, 35000000.0, 20000000.0, 12000000.0]}

# %% [markdown]
# # After many an error, we have found a way!

# %%
genreList
# Out:
# ['Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western']

# %%
def toConcat():
    concatList = []
    for i in genreList:
        thisDF = pd.DataFrame(getGenreInfo(i))
        concatList.append(thisDF)
    return concatList

# %%
GenreDF = pd.concat(toConcat())
GenreDF
# Out:
#                 Title    Genre  Domestic Gross  Foreign Gross  \
# 0                 '71   Action       1300000.0       355000.0
# 1           12 Rounds   Action      12234694.0      5071954.0
# 2           12 Strong   Action      45800000.0     21600000.0
# 3        13 Assassins   Action        803000.0     16800000.0
# 4           14 Blades   Action             0.0      3800000.0
# ..                ...      ...             ...            ...
# 30  The Warrior's Way  Western       5700000.0      5400000.0
# 31           Trespass  Western         16816.0       769716.0
# 32          True Grit  Western     171200000.0     81000000.0
# 33        Wild Things  Western      29795299.0     25781400.0
# 34            Witness  Western      65532576.0            0.0
#
#     Worldwide Gross  Production Budget
# 0         1655000.0                0.0
# 1        17306648.0         20000000.0
# 2        71118378.0         35000000.0
# 3        17603000.0                0.0
# 4         3800000.0                0.0
# ..              ...                ...
# 30        8514325.0         42000000.0
# 31         786532.0         35000000.0
# 32      252276928.0         35000000.0
# 33       55576699.0         20000000.0
# 34       65532576.0         12000000.0
#
# [10941 rows x 6 columns]

# %%
GenreDF2 = GenreDF.reset_index()
GenreDF2
# Out:
#        index              Title    Genre  Domestic Gross  Foreign Gross  \
# 0          0                '71   Action       1300000.0       355000.0
# 1          1          12 Rounds   Action      12234694.0      5071954.0
# 2          2          12 Strong   Action      45800000.0     21600000.0
# 3          3       13 Assassins   Action        803000.0     16800000.0
# 4          4          14 Blades   Action             0.0      3800000.0
# ...      ...                ...      ...             ...            ...
# 10936     30  The Warrior's Way  Western       5700000.0      5400000.0
# 10937     31           Trespass  Western         16816.0       769716.0
# 10938     32          True Grit  Western     171200000.0     81000000.0
# 10939     33        Wild Things  Western      29795299.0     25781400.0
# 10940     34            Witness  Western      65532576.0            0.0
#
#        Worldwide Gross  Production Budget
# 0            1655000.0                0.0
# 1           17306648.0         20000000.0
# 2           71118378.0         35000000.0
# 3           17603000.0                0.0
# 4            3800000.0                0.0
# ...                ...                ...
# 10936        8514325.0         42000000.0
# 10937         786532.0         35000000.0
# 10938      252276928.0         35000000.0
# 10939       55576699.0         20000000.0
# 10940       65532576.0         12000000.0
#
# [10941 rows x 7 columns]

# %% [markdown]
# # Try to plot:

# %%
g = sns.catplot(x= 'Genre', y= 'Worldwide Gross', hue ='Production Budget', kind='violin', data = GenreDF2)

g.fig.set_figwidth(20)
g.fig.set_figheight(10)

# %% [markdown]
# - Too much information, let's break it down a little more

# %%
def returnRate():
    returnRate = []
    for i in GenreDF.index:
        thisGross = GenreDF['Worldwide Gross'][i]
        thisBudget = GenreDF['Production Budget'][i]
        thisIncrease = thisGross - thisBudget
        thisRate = (thisIncrease / thisBudget) * 100
        returnRate.append(thisRate)
    return(returnRate)

# %% [markdown]
# - This returnRate function brought divide by zero errors. So I reset the index to the DF.

# %% [markdown]
# # Worldwide Stats

# %% [markdown]
# ## We're Getting Somewhere!

# %%
def returnRate2():
    returnRate = []
    for i in GenreDF2.index:
        thisBudget = (GenreDF2['Production Budget'][i])
        if (thisBudget == 0):
            thisRate = 0.0
        else:
            thisGross = GenreDF2['Worldwide Gross'][i]
            thisRate = (thisGross / thisBudget) * 100
        returnRate.append(thisRate)
    return(returnRate)

# %%
GenreDF2['Return Rate Worldwide'] = returnRate2()

# %%
GenreDF2
# Out:
#        index              Title    Genre  Domestic Gross  Foreign Gross  \
# 0          0                '71   Action       1300000.0       355000.0
# 1          1          12 Rounds   Action      12234694.0      5071954.0
# 2          2          12 Strong   Action      45800000.0     21600000.0
# 3          3       13 Assassins   Action        803000.0     16800000.0
# 4          4          14 Blades   Action             0.0      3800000.0
# ...      ...                ...      ...             ...            ...
# 10936     30  The Warrior's Way  Western       5700000.0      5400000.0
# 10937     31           Trespass  Western         16816.0       769716.0
# 10938     32          True Grit  Western     171200000.0     81000000.0
# 10939     33        Wild Things  Western      29795299.0     25781400.0
# 10940     34            Witness  Western      65532576.0            0.0
#
#        Worldwide Gross  Production Budget  Return Rate Worldwide
# 0            1655000.0                0.0               0.000000
# 1           17306648.0         20000000.0              86.533240
# 2           71118378.0         35000000.0             203.195366
# 3           17603000.0                0.0               0.000000
# 4            3800000.0                0.0               0.000000
# ...                ...                ...                    ...
# 10936        8514325.0         42000000.0              20.272202
# 10937         786532.0         35000000.0               2.247234
# 10938      252276928.0         35000000.0             720.791223
# 10939       55576699.0         20000000.0             277.883495
# 10940       65532576.0         12000000.0             546.104800
#
# [10941 rows x 8 columns]

# %%
def returnRateDom():
    returnRate = []
    for i in GenreDF2.index:
        thisBudget = (GenreDF2['Production Budget'][i])
        if (thisBudget == 0):
            thisRate = 0.0
        else:
            thisGross = GenreDF2['Domestic Gross'][i]
            thisRate = (thisGross / thisBudget) * 100
        returnRate.append(thisRate)
    return(returnRate)

# %%
GenreDF2['Return Rate Domestic'] = returnRateDom()
GenreDF2
# Out:
#        index              Title    Genre  Domestic Gross  Foreign Gross  \
# 0          0                '71   Action       1300000.0       355000.0
# 1          1          12 Rounds   Action      12234694.0      5071954.0
# 2          2          12 Strong   Action      45800000.0     21600000.0
# 3          3       13 Assassins   Action        803000.0     16800000.0
# 4          4          14 Blades   Action             0.0      3800000.0
# ...      ...                ...      ...             ...            ...
# 10936     30  The Warrior's Way  Western       5700000.0      5400000.0
# 10937     31           Trespass  Western         16816.0       769716.0
# 10938     32          True Grit  Western     171200000.0     81000000.0
# 10939     33        Wild Things  Western      29795299.0     25781400.0
# 10940     34            Witness  Western      65532576.0            0.0
#
#        Worldwide Gross  Production Budget  Return Rate Worldwide  \
# 0            1655000.0                0.0               0.000000
# 1           17306648.0         20000000.0              86.533240
# 2           71118378.0         35000000.0             203.195366
# 3           17603000.0                0.0               0.000000
# 4            3800000.0                0.0               0.000000
# ...                ...                ...                    ...
# 10936        8514325.0         42000000.0              20.272202
# 10937         786532.0         35000000.0               2.247234
# 10938      252276928.0         35000000.0             720.791223
# 10939       55576699.0         20000000.0             277.883495
# 10940       65532576.0         12000000.0             546.104800
#
#        Return Rate Domestic
# 0                  0.000000
# 1                 61.173470
# 2                130.857143
# 3                  0.000000
# 4                  0.000000
# ...                     ...
# 10936             13.571429
# 10937              0.048046
# 10938            489.142857
# 10939            148.976495
# 10940            546.104800
#
# [10941 rows x 9 columns]

# %% [markdown]
# ## Try plotting again:

# %%
g = sns.catplot(x= 'Genre', y= 'Return Rate Worldwide', kind='violin', data = GenreDF2)

g.fig.set_figwidth(20)
g.fig.set_figheight(10)

# %% [markdown]
# - What if we focus on the top grossing genres, and then plot the rate of return on those?

# %%
GenreGross= GenreDF2.loc[(GenreDF2['Genre']== 'Action')    |
                         (GenreDF2['Genre']== 'Adventure') |
                         (GenreDF2['Genre']== 'Animation') |
                         (GenreDF2['Genre']== 'Fantasy')   |
                         (GenreDF2['Genre']== 'Sci-Fi')    |
                         (GenreDF2['Genre']== 'Musical')]

# %%
# %store GenreGross
# Out:
# Stored 'GenreGross' (DataFrame)

# %%
GenreGross
# Out:
#       index                       Title   Genre  Domestic Gross  \
# 0         0                         '71  Action       1300000.0
# 1         1                   12 Rounds  Action      12234694.0
# 2         2                   12 Strong  Action      45800000.0
# 3         3                13 Assassins  Action        803000.0
# 4         4                   14 Blades  Action             0.0
# ...     ...                         ...     ...             ...
# 9962    230           X-Men: Apocalypse  Sci-Fi     155400000.0
# 9963    231  X-Men: Days of Future Past  Sci-Fi     233900000.0
# 9964    232          X-Men: First Class  Sci-Fi     146400000.0
# 9965    233                         Yes  Sci-Fi        396035.0
# 9966    234             Z for Zachariah  Sci-Fi        121000.0
#
#       Foreign Gross  Worldwide Gross  Production Budget  \
# 0          355000.0        1655000.0                0.0
# 1         5071954.0       17306648.0         20000000.0
# 2        21600000.0       71118378.0         35000000.0
# 3        16800000.0       17603000.0                0.0
# 4         3800000.0        3800000.0                0.0
# ...             ...              ...                ...
# 9962    388500000.0      542537546.0        178000000.0
# 9963    513900000.0      747862775.0        200000000.0
# 9964    207200000.0      355408305.0        160000000.0
# 9965       265186.0         661221.0          1700000.0
# 9966            0.0         121000.0                0.0
#
#       Return Rate Worldwide  Return Rate Domestic
# 0                  0.000000              0.000000
# 1                 86.533240             61.173470
# 2                203.195366            130.857143
# 3                  0.000000              0.000000
# 4                  0.000000              0.000000
# ...                     ...                   ...
# 9962             304.796374             87.303371
# 9963             373.931388            116.950000
# 9964             222.130191             91.500000
# 9965              38.895353             23.296176
# 9966               0.000000              0.000000
#
# [2280 rows x 9 columns]

# %%
GenreGross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2280 entries, 0 to 9966
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  2280 non-null   int64
#  1   Title                  2280 non-null   object
#  2   Genre                  2280 non-null   object
#  3   Domestic Gross         2280 non-null   float64
#  4   Foreign Gross          2280 non-null   float64
#  5   Worldwide Gross        2280 non-null   float64
#  6   Production Budget      2280 non-null   float64
#  7   Return Rate Worldwide  2280 non-null   float64
#  8   Return Rate Domestic   2280 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 178.1+ KB

# %%
g = sns.catplot(x= 'Genre', y= 'Return Rate Worldwide', kind='violin', data = GenreGross)

g.fig.set_figwidth(20)
g.fig.set_figheight(10)

# %% [markdown]
# ## Getting Ever Closer

# %% [markdown]
# - We still need to make this graph more readable, also need to have hard numbers.

# %%
GenreGross2 = GenreGross.loc[GenreGross['Return Rate Worldwide'] < 1000]

# %%
GenreGross2
# Out:
#       index                       Title   Genre  Domestic Gross  \
# 0         0                         '71  Action       1300000.0
# 1         1                   12 Rounds  Action      12234694.0
# 2         2                   12 Strong  Action      45800000.0
# 3         3                13 Assassins  Action        803000.0
# 4         4                   14 Blades  Action             0.0
# ...     ...                         ...     ...             ...
# 9962    230           X-Men: Apocalypse  Sci-Fi     155400000.0
# 9963    231  X-Men: Days of Future Past  Sci-Fi     233900000.0
# 9964    232          X-Men: First Class  Sci-Fi     146400000.0
# 9965    233                         Yes  Sci-Fi        396035.0
# 9966    234             Z for Zachariah  Sci-Fi        121000.0
#
#       Foreign Gross  Worldwide Gross  Production Budget  \
# 0          355000.0        1655000.0                0.0
# 1         5071954.0       17306648.0         20000000.0
# 2        21600000.0       71118378.0         35000000.0
# 3        16800000.0       17603000.0                0.0
# 4         3800000.0        3800000.0                0.0
# ...             ...              ...                ...
# 9962    388500000.0      542537546.0        178000000.0
# 9963    513900000.0      747862775.0        200000000.0
# 9964    207200000.0      355408305.0        160000000.0
# 9965       265186.0         661221.0          1700000.0
# 9966            0.0         121000.0                0.0
#
#       Return Rate Worldwide  Return Rate Domestic
# 0                  0.000000              0.000000
# 1                 86.533240             61.173470
# 2                203.195366            130.857143
# 3                  0.000000              0.000000
# 4                  0.000000              0.000000
# ...                     ...                   ...
# 9962             304.796374             87.303371
# 9963             373.931388            116.950000
# 9964             222.130191             91.500000
# 9965              38.895353             23.296176
# 9966               0.000000              0.000000
#
# [2179 rows x 9 columns]

# %%
g = sns.catplot(x= 'Genre', y= 'Return Rate Worldwide', kind='violin', data = GenreGross2, palette =(sns.color_palette("husl", 6)))
g.fig.suptitle('Worldwide ROI by Top Genre')
g.fig.set_figwidth(18)
g.fig.set_figheight(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-be1f74e0eea1> in <module>
# ----> 1 g = sns.catplot(x= 'Genre', y= 'Return Rate Worldwide', kind='violin', data = GenreGross2, palette =(sns.color_palette("husl", 6)))
#       2 g.fig.suptitle('Worldwide ROI by Top Genre')
#       3 g.fig.set_figwidth(18)
#       4 g.fig.set_figheight(10)
#
# NameError: name 'GenreGross2' is not defined

# %%
GenreGross3 = GenreGross.loc[GenreGross['Return Rate Worldwide'] < 200]

# %%
g = sns.catplot(x= 'Genre', y= 'Return Rate Worldwide', kind='violin', data = GenreGross3, palette =(sns.color_palette("husl", 6)))

g.fig.set_figwidth(18)
g.fig.set_figheight(10)

# %% [markdown]
# # Domestic Stats

# %%
GenreGross4 = GenreGross.loc[GenreGross['Return Rate Domestic'] < 200]

# %%
# %store GenreGross4
# Out:
# Stored 'GenreGross4' (DataFrame)

# %%
GenreGross4
# Out:
#       index                       Title   Genre  Domestic Gross  \
# 0         0                         '71  Action       1300000.0
# 1         1                   12 Rounds  Action      12234694.0
# 2         2                   12 Strong  Action      45800000.0
# 3         3                13 Assassins  Action        803000.0
# 4         4                   14 Blades  Action             0.0
# ...     ...                         ...     ...             ...
# 9962    230           X-Men: Apocalypse  Sci-Fi     155400000.0
# 9963    231  X-Men: Days of Future Past  Sci-Fi     233900000.0
# 9964    232          X-Men: First Class  Sci-Fi     146400000.0
# 9965    233                         Yes  Sci-Fi        396035.0
# 9966    234             Z for Zachariah  Sci-Fi        121000.0
#
#       Foreign Gross  Worldwide Gross  Production Budget  \
# 0          355000.0        1655000.0                0.0
# 1         5071954.0       17306648.0         20000000.0
# 2        21600000.0       71118378.0         35000000.0
# 3        16800000.0       17603000.0                0.0
# 4         3800000.0        3800000.0                0.0
# ...             ...              ...                ...
# 9962    388500000.0      542537546.0        178000000.0
# 9963    513900000.0      747862775.0        200000000.0
# 9964    207200000.0      355408305.0        160000000.0
# 9965       265186.0         661221.0          1700000.0
# 9966            0.0         121000.0                0.0
#
#       Return Rate Worldwide  Return Rate Domestic
# 0                  0.000000              0.000000
# 1                 86.533240             61.173470
# 2                203.195366            130.857143
# 3                  0.000000              0.000000
# 4                  0.000000              0.000000
# ...                     ...                   ...
# 9962             304.796374             87.303371
# 9963             373.931388            116.950000
# 9964             222.130191             91.500000
# 9965              38.895353             23.296176
# 9966               0.000000              0.000000
#
# [1952 rows x 9 columns]

# %%
g = sns.catplot(x= 'Genre', y= 'Return Rate Domestic', kind='violin', data = GenreGross4, palette =(sns.color_palette("husl", 6)))

g.fig.set_figwidth(18)
g.fig.set_figheight(10)

# %% [markdown]
# # Plotting Based off of Popularity to Return Rate

# %% [markdown]
# ### Most Popular Genres:
#     Drama, Documentary, Comedy, Horror, Action, Thriller

# %%
GenrePop = GenreDF2.loc[(GenreDF2['Genre']== 'Drama')       |
                        (GenreDF2['Genre']== 'Documentary') |
                        (GenreDF2['Genre']== 'Comedy')      |
                        (GenreDF2['Genre']== 'Horror')      |
                        (GenreDF2['Genre']== 'Action')      |
                        (GenreDF2['Genre']== 'Thriller')]

# %%
GenrePop
# Out:
#        index                       Title     Genre  Domestic Gross  \
# 0          0                         '71    Action       1300000.0
# 1          1                   12 Rounds    Action      12234694.0
# 2          2                   12 Strong    Action      45800000.0
# 3          3                13 Assassins    Action        803000.0
# 4          4                   14 Blades    Action             0.0
# ...      ...                         ...       ...             ...
# 10811    747             Z for Zachariah  Thriller        121000.0
# 10812    748            Zero Dark Thirty  Thriller      95700000.0
# 10813    749                        Zoom  Thriller      11989328.0
# 10814    750                        Zulu  Thriller             0.0
# 10815    751  xXx: Return of Xander Cage  Thriller      44898413.0
#
#        Foreign Gross  Worldwide Gross  Production Budget  \
# 0           355000.0        1655000.0                0.0
# 1          5071954.0       17306648.0         20000000.0
# 2         21600000.0       71118378.0         35000000.0
# 3         16800000.0       17603000.0                0.0
# 4          3800000.0        3800000.0                0.0
# ...              ...              ...                ...
# 10811            0.0         121000.0                0.0
# 10812     37100000.0      134612435.0         52500000.0
# 10813       516860.0       12506188.0         35000000.0
# 10814      1844228.0        1844228.0         16000000.0
# 10815    300134946.0      345033359.0         85000000.0
#
#        Return Rate Worldwide  Return Rate Domestic
# 0                   0.000000              0.000000
# 1                  86.533240             61.173470
# 2                 203.195366            130.857143
# 3                   0.000000              0.000000
# 4                   0.000000              0.000000
# ...                      ...                   ...
# 10811               0.000000              0.000000
# 10812             256.404638            182.285714
# 10813              35.731966             34.255223
# 10814              11.526425              0.000000
# 10815             405.921599             52.821662
#
# [6846 rows x 9 columns]

# %% [markdown]
# # Worldwide

# %%
GenrePop2 = GenrePop.loc[GenrePop['Return Rate Worldwide'] < 200]

# %%
g = sns.catplot(x= 'Genre', y= 'Return Rate Worldwide', kind='violin', data = GenrePop2, palette =(sns.color_palette("husl", 6)))

g.fig.set_figwidth(18)
g.fig.set_figheight(10)

# %% [markdown]
# # Domestic

# %%
GenrePop3 = GenrePop.loc[GenrePop['Return Rate Domestic'] < 200]

# %%
GenrePop3
# Out:
#        index                       Title     Genre  Domestic Gross  \
# 0          0                         '71    Action       1300000.0
# 1          1                   12 Rounds    Action      12234694.0
# 2          2                   12 Strong    Action      45800000.0
# 3          3                13 Assassins    Action        803000.0
# 4          4                   14 Blades    Action             0.0
# ...      ...                         ...       ...             ...
# 10811    747             Z for Zachariah  Thriller        121000.0
# 10812    748            Zero Dark Thirty  Thriller      95700000.0
# 10813    749                        Zoom  Thriller      11989328.0
# 10814    750                        Zulu  Thriller             0.0
# 10815    751  xXx: Return of Xander Cage  Thriller      44898413.0
#
#        Foreign Gross  Worldwide Gross  Production Budget  \
# 0           355000.0        1655000.0                0.0
# 1          5071954.0       17306648.0         20000000.0
# 2         21600000.0       71118378.0         35000000.0
# 3         16800000.0       17603000.0                0.0
# 4          3800000.0        3800000.0                0.0
# ...              ...              ...                ...
# 10811            0.0         121000.0                0.0
# 10812     37100000.0      134612435.0         52500000.0
# 10813       516860.0       12506188.0         35000000.0
# 10814      1844228.0        1844228.0         16000000.0
# 10815    300134946.0      345033359.0         85000000.0
#
#        Return Rate Worldwide  Return Rate Domestic
# 0                   0.000000              0.000000
# 1                  86.533240             61.173470
# 2                 203.195366            130.857143
# 3                   0.000000              0.000000
# 4                   0.000000              0.000000
# ...                      ...                   ...
# 10811               0.000000              0.000000
# 10812             256.404638            182.285714
# 10813              35.731966             34.255223
# 10814              11.526425              0.000000
# 10815             405.921599             52.821662
#
# [5775 rows x 9 columns]

# %%
g = sns.catplot(x= 'Genre', y= 'Return Rate Domestic', kind='violin', data = GenrePop3, palette =(sns.color_palette("husl", 6)))

g.fig.set_figwidth(18)
g.fig.set_figheight(10)

# %% [markdown]
# # Final Top Genres

# %%
GenrePopMaster = GenreDF2.loc[(GenreDF2['Genre']== 'Musical')  |
                              (GenreDF2['Genre']== 'Action')   |
                              (GenreDF2['Genre']== 'Adventure')|
                              (GenreDF2['Genre']== 'Animation')|
                              (GenreDF2['Genre']== 'Drama') ]

GenrePopMaster = GenrePopMaster.loc[GenrePopMaster['Return Rate Domestic'] < 200]

# %%
# %store GenrePopMaster
# Out:
# Stored 'GenrePopMaster' (DataFrame)

# %%
g = sns.catplot(x= 'Genre', y= 'Return Rate Domestic', kind='violin', data = GenrePopMaster, palette =(sns.color_palette("husl", 5)))

g.fig.set_figwidth(18)
g.fig.set_figheight(10)
