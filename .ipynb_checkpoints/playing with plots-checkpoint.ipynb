# %%
# %store -r df
# %store -r dftitcrew
# %store -r Genredf

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from importlib import reload
import functions as fun

reload(fun)
# Out:
# <module 'functions' from 'C:\\Users\\damni\\flatiron-ds-course\\mod1proj\\Prjoect\\functions.py'>

# %%
df.head()
# Out:
#   studio  domestic_gross  foreign_gross    year  release_date  \
# 0  RAtt.       1300000.0       355000.0  2015.0           NaN
# 1     FM         53900.0            0.0  2014.0           NaN
# 2   Par.      72100000.0     38100000.0  2016.0  Mar 11, 2016
# 3    NaN         14616.0            0.0     NaN  Nov 11, 2015
# 4  Anch.        203000.0            0.0  2012.0           NaN
#
#    production_budget  worldwide_gross  start_year  runtime_minutes  \
# 0                0.0        1655000.0      2014.0             99.0
# 1                0.0          53900.0      2013.0            117.0
# 2          5000000.0      108286422.0      2016.0            103.0
# 3         12000000.0          14616.0      2015.0            111.0
# 4                0.0         203000.0      2011.0            100.0
#
#                   genres  averagerating  numvotes   movie_id  \
# 0  Action,Drama,Thriller            7.2   46103.0  tt2614684
# 1              Drama,War            7.1    6848.0  tt2353767
# 2   Drama,Horror,Mystery            7.2  260383.0  tt1179933
# 3                  Drama            6.7    1114.0  tt3453052
# 4   Comedy,Drama,Romance            6.1   22484.0  tt1715873
#
#                movie_name                 genresList
# 0                     '71  [Action, Drama, Thriller]
# 1  1,000 Times Good Night               [Drama, War]
# 2     10 Cloverfield Lane   [Drama, Horror, Mystery]
# 3   10 Days in a Madhouse                    [Drama]
# 4                10 Years   [Comedy, Drama, Romance]

# %%
dfcrew = dftitcrew.fillna('nm')

# %%
dfcrew['writersList'] = fun.splitNewCol(dfcrew, 'writers')
dfcrew['directorsList'] = fun.splitNewCol(dfcrew, 'directors')

# %%
dfcrew = dfcrew.drop(['directors', 'writers'], axis = 1)

# %%
dfcrew.head()
# Out:
#       tconst             writersList                      directorsList
# 0  tt0285252             [nm0899854]                        [nm0899854]
# 1  tt0438973  [nm0175726, nm1802864]                               [nm]
# 2  tt0462036             [nm1940585]                        [nm1940585]
# 3  tt0835418  [nm0310087, nm0841532]                        [nm0151540]
# 4  tt0878654             [nm0284943]  [nm0089502, nm2291498, nm2292011]

# %%
dfcrew['writerCount'] = fun.countNewCol(dfcrew, 'writersList')
dfcrew['directorCount'] = fun.countNewCol(dfcrew, 'directorsList')

# %%
dfcrew.head()
# Out:
#       tconst             writersList                      directorsList  \
# 0  tt0285252             [nm0899854]                        [nm0899854]
# 1  tt0438973  [nm0175726, nm1802864]                               [nm]
# 2  tt0462036             [nm1940585]                        [nm1940585]
# 3  tt0835418  [nm0310087, nm0841532]                        [nm0151540]
# 4  tt0878654             [nm0284943]  [nm0089502, nm2291498, nm2292011]
#
#    writerCount  directorCount
# 0            1              1
# 1            2              1
# 2            1              1
# 3            2              1
# 4            1              3

# %%
dfcrew2 = dfcrew.drop(['writersList', 'directorsList'], axis = 1)

# %%
dfcrew2 = dfcrew2.set_index('tconst')

# %%
dfcrew2.head()
# Out:
#            writerCount  directorCount
# tconst
# tt0285252            1              1
# tt0438973            2              1
# tt0462036            1              1
# tt0835418            2              1
# tt0878654            1              3

# %%
df = df.set_index('movie_id')

# %%
df.head()
# Out:
#           studio  domestic_gross  foreign_gross    year  release_date  \
# movie_id
# tt2614684  RAtt.       1300000.0       355000.0  2015.0           NaN
# tt2353767     FM         53900.0            0.0  2014.0           NaN
# tt1179933   Par.      72100000.0     38100000.0  2016.0  Mar 11, 2016
# tt3453052    NaN         14616.0            0.0     NaN  Nov 11, 2015
# tt1715873  Anch.        203000.0            0.0  2012.0           NaN
#
#            production_budget  worldwide_gross  start_year  runtime_minutes  \
# movie_id
# tt2614684                0.0        1655000.0      2014.0             99.0
# tt2353767                0.0          53900.0      2013.0            117.0
# tt1179933          5000000.0      108286422.0      2016.0            103.0
# tt3453052         12000000.0          14616.0      2015.0            111.0
# tt1715873                0.0         203000.0      2011.0            100.0
#
#                           genres  averagerating  numvotes  \
# movie_id
# tt2614684  Action,Drama,Thriller            7.2   46103.0
# tt2353767              Drama,War            7.1    6848.0
# tt1179933   Drama,Horror,Mystery            7.2  260383.0
# tt3453052                  Drama            6.7    1114.0
# tt1715873   Comedy,Drama,Romance            6.1   22484.0
#
#                        movie_name                 genresList
# movie_id
# tt2614684                     '71  [Action, Drama, Thriller]
# tt2353767  1,000 Times Good Night               [Drama, War]
# tt1179933     10 Cloverfield Lane   [Drama, Horror, Mystery]
# tt3453052   10 Days in a Madhouse                    [Drama]
# tt1715873                10 Years   [Comedy, Drama, Romance]

# %%
df = df.join(dfcrew2)

# %%
df.head()
# Out:
#             studio  domestic_gross  foreign_gross    year  release_date  \
# tt0249516      NaN             0.0        73706.0     NaN  Dec 31, 2012
# tt0293429      NaN      70433227.0     51700000.0     NaN  Aug 18, 1995
# tt0315642  Relbig.       1100000.0            0.0  2016.0           NaN
# tt0337692      IFC        744000.0      8000000.0  2012.0  Mar 22, 2013
# tt0359950      Fox      58200000.0    129900000.0  2013.0  Dec 25, 2013
#
#            production_budget  worldwide_gross  start_year  runtime_minutes  \
# tt0249516         45000000.0          73706.0      2012.0             91.0
# tt0293429         20000000.0      122133227.0      2021.0              NaN
# tt0315642                0.0        1100000.0      2016.0            103.0
# tt0337692         25000000.0        9313302.0      2012.0            124.0
# tt0359950         91000000.0      187861183.0      2013.0            114.0
#
#                              genres  averagerating  numvotes  \
# tt0249516   Action,Animation,Comedy            1.9    8248.0
# tt0293429  Action,Adventure,Fantasy            NaN       NaN
# tt0315642        Action,Crime,Drama            7.1   15378.0
# tt0337692   Adventure,Drama,Romance            6.1   37886.0
# tt0359950    Adventure,Comedy,Drama            7.3  275300.0
#
#                                 movie_name                    genresList  \
# tt0249516                       Foodfight!   [Action, Animation, Comedy]
# tt0293429                    Mortal Kombat  [Action, Adventure, Fantasy]
# tt0315642                            Wazir        [Action, Crime, Drama]
# tt0337692                      On the Road   [Adventure, Drama, Romance]
# tt0359950  The Secret Life of Walter Mitty    [Adventure, Comedy, Drama]
#
#            writerCount  directorCount
# tt0249516            5              1
# tt0293429            1              1
# tt0315642            8              1
# tt0337692            2              1
# tt0359950            2              1

# %%
grouped = df.groupby(['directorCount', 'writerCount'])[['domestic_gross', 'foreign_gross', 'production_budget', 'worldwide_gross', 'runtime_minutes', 'averagerating', 'numvotes']]

# %%
df2 = df[df.directorCount < 6]
# %store df2
# Out:
# Stored 'df2' (DataFrame)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5152 entries, tt0249516 to tt9906218
# Data columns (total 16 columns):
# studio               3335 non-null object
# domestic_gross       5152 non-null float64
# foreign_gross        5152 non-null float64
# year                 3338 non-null float64
# release_date         3387 non-null object
# production_budget    5152 non-null float64
# worldwide_gross      5152 non-null float64
# start_year           5152 non-null float64
# runtime_minutes      4703 non-null float64
# genres               5152 non-null object
# averagerating        4221 non-null float64
# numvotes             4221 non-null float64
# movie_name           5152 non-null object
# genresList           5152 non-null object
# writerCount          5152 non-null int64
# directorCount        5152 non-null int64
# dtypes: float64(9), int64(2), object(5)
# memory usage: 684.2+ KB

# %%
df.loc[df['directorCount'] == 34]
# Out:
#           studio  domestic_gross  foreign_gross    year release_date  \
# tt1687247    NGE        253000.0            0.0  2011.0          NaN
#
#            production_budget  worldwide_gross  start_year  runtime_minutes  \
# tt1687247                0.0         253000.0      2011.0             95.0
#
#                       genres  averagerating  numvotes     movie_name  \
# tt1687247  Documentary,Drama            7.7   14367.0  Life in a Day
#
#                      genresList  writerCount  directorCount
# tt1687247  [Documentary, Drama]            1             34

# %%
df['directorCount'].value_counts()
# Out:
# 1     4700
# 2      403
# 3       34
# 4       10
# 5        5
# 6        4
# 10       3
# 8        3
# 7        2
# 13       2
# 9        2
# 34       1
# 12       1
# Name: directorCount, dtype: int64

# %%
df['writerCount'].value_counts()
# Out:
# 1     2456
# 2     1422
# 3      693
# 4      290
# 5      158
# 6       62
# 7       35
# 8       19
# 9       13
# 10      10
# 11       5
# 13       2
# 12       1
# 15       1
# 20       1
# 14       1
# 25       1
# Name: writerCount, dtype: int64

# %%
grouped.count()
# Out:
#                            domestic_gross  foreign_gross  production_budget  \
# directorCount writerCount
# 1             1                      2280           2280               2280
#               2                      1298           1298               1298
#               3                       623            623                623
#               4                       254            254                254
#               5                       134            134                134
#               6                        49             49                 49
#               7                        29             29                 29
#               8                        12             12                 12
#               9                         8              8                  8
#               10                        8              8                  8
#               11                        2              2                  2
#               13                        1              1                  1
#               14                        1              1                  1
#               25                        1              1                  1
# 2             1                       154            154                154
#               2                       117            117                117
#               3                        61             61                 61
#               4                        31             31                 31
#               5                        18             18                 18
#               6                        10             10                 10
#               7                         4              4                  4
#               8                         4              4                  4
#               9                         2              2                  2
#               10                        1              1                  1
#               12                        1              1                  1
# 3             1                        10             10                 10
#               2                         7              7                  7
#               3                         7              7                  7
#               4                         3              3                  3
#               5                         1              1                  1
#               6                         2              2                  2
#               8                         2              2                  2
#               9                         2              2                  2
# 4             1                         5              5                  5
#               3                         2              2                  2
#               4                         1              1                  1
#               5                         1              1                  1
#               8                         1              1                  1
# 5             1                         1              1                  1
#               4                         1              1                  1
#               5                         2              2                  2
#               9                         1              1                  1
# 6             1                         1              1                  1
#               6                         1              1                  1
#               7                         1              1                  1
#               10                        1              1                  1
# 7             5                         1              1                  1
#               7                         1              1                  1
# 8             1                         2              2                  2
#               5                         1              1                  1
# 9             1                         1              1                  1
#               13                        1              1                  1
# 10            1                         1              1                  1
#               11                        2              2                  2
# 12            15                        1              1                  1
# 13            11                        1              1                  1
#               20                        1              1                  1
# 34            1                         1              1                  1
#
#                            worldwide_gross  runtime_minutes  averagerating  \
# directorCount writerCount
# 1             1                       2280             1977           1606
#               2                       1298             1223           1171
#               3                        623              600            595
#               4                        254              248            248
#               5                        134              133            132
#               6                         49               48             49
#               7                         29               29             29
#               8                         12               12             12
#               9                          8                7              7
#               10                         8                8              7
#               11                         2                2              2
#               13                         1                1              1
#               14                         1                1              1
#               25                         1                1              1
# 2             1                        154              136            104
#               2                        117              108             97
#               3                         61               59             59
#               4                         31               30             29
#               5                         18               16             16
#               6                         10               10             10
#               7                          4                4              4
#               8                          4                4              4
#               9                          2                2              2
#               10                         1                1              1
#               12                         1                1              1
# 3             1                         10                7              3
#               2                          7                6              6
#               3                          7                7              7
#               4                          3                2              2
#               5                          1                1              1
#               6                          2                2              2
#               8                          2                2              2
#               9                          2                1              2
# 4             1                          5                5              1
#               3                          2                2              1
#               4                          1                0              0
#               5                          1                1              0
#               8                          1                1              1
# 5             1                          1                1              1
#               4                          1                1              1
#               5                          2                2              2
#               9                          1                1              1
# 6             1                          1                1              1
#               6                          1                0              0
#               7                          1                1              1
#               10                         1                1              1
# 7             5                          1                1              1
#               7                          1                1              1
# 8             1                          2                2              1
#               5                          1                1              1
# 9             1                          1                0              1
#               13                         1                1              1
# 10            1                          1                1              0
#               11                         2                2              2
# 12            15                         1                1              1
# 13            11                         1                0              1
#               20                         1                1              1
# 34            1                          1                1              1
#
#                            numvotes
# directorCount writerCount
# 1             1                1606
#               2                1171
#               3                 595
#               4                 248
#               5                 132
#               6                  49
#               7                  29
#               8                  12
#               9                   7
#               10                  7
#               11                  2
#               13                  1
#               14                  1
#               25                  1
# 2             1                 104
#               2                  97
#               3                  59
#               4                  29
#               5                  16
#               6                  10
#               7                   4
#               8                   4
#               9                   2
#               10                  1
#               12                  1
# 3             1                   3
#               2                   6
#               3                   7
#               4                   2
#               5                   1
#               6                   2
#               8                   2
#               9                   2
# 4             1                   1
#               3                   1
#               4                   0
#               5                   0
#               8                   1
# 5             1                   1
#               4                   1
#               5                   2
#               9                   1
# 6             1                   1
#               6                   0
#               7                   1
#               10                  1
# 7             5                   1
#               7                   1
# 8             1                   1
#               5                   1
# 9             1                   1
#               13                  1
# 10            1                   0
#               11                  2
# 12            15                  1
# 13            11                  1
#               20                  1
# 34            1                   1

# %%
grouped1 = df.groupby(['directorCount', 'writerCount'])[['worldwide_gross', 'production_budget']].mean()

# %%
fig, ax = plt.subplots(figsize = (10,20))
ax.set_xlim([0,10])
plt.title('Title')
df2.groupby(['directorCount', 'writerCount']).count()['worldwide_gross'].unstack().plot(kind = 'barh', ax=ax)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax.set_ylim([0 ,900000000])
df2.groupby(['directorCount', 'writerCount']).mean()['worldwide_gross'].unstack().plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax.set_ylim([0 ,600000000])
df2.groupby(['directorCount', 'writerCount']).mean()['domestic_gross'].unstack().plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize = (18,15))
ax.set_ylim([0 ,180000000])
df2.groupby(['directorCount', 'writerCount']).mean()['production_budget'].unstack().plot(ax=ax)

# %%
#plt.figure(figsize = (30,18))
sns.catplot(x='directorCount', y = 'worldwide_gross', hue = 'writerCount',  data = df2)

# %%
#fig, ax = plt.subplots(figsize = (15,18))
sns.catplot(x='directorCount', y = 'production_budget', hue = 'writerCount',  data = df2);

# %%
newfig = plt.figure(figsize = (15,15))
ax = newfig.add_subplot(121, title='Test')
ax2 = newfig.add_subplot(122)
#ax.title('test title')
sns.catplot(x='directorCount', y = 'worldwide_gross', hue = 'writerCount',  data = df2.query('writerCount < 11'), ax = ax)
sns.catplot(x='directorCount', y = 'production_budget', hue = 'writerCount',  data = df2.query('writerCount < 11'), ax = ax2)

plt.close(2)
plt.close(3)

# %%
newfig = plt.figure(figsize = (25,15))
ax = newfig.add_subplot(121)
ax2 = newfig.add_subplot(122)
sns.catplot(x='production_budget', y = 'worldwide_gross', hue = 'writerCount',  data = df2.query('writerCount < 11'), ax = ax)
sns.catplot(x='production_budget', y = 'worldwide_gross', hue = 'directorCount',  data = df2.query('production_budget > 0'), ax = ax2)
plt.close(2)
plt.close(3)

# %%
fig, ax = plt.subplots(figsize = (12,12))
ax.set_title('title')
ax.set_ylim([0 ,1200000000])
sns.catplot(x='directorCount', y = 'worldwide_gross', kind = 'boxen', data = df2, ax=ax)
plt.close(2)

# %%
fig, ax = plt.subplots(figsize = (12,12))
ax.set_ylim([0 ,1200000000])
sns.catplot(x='writerCount', y = 'worldwide_gross', kind = 'boxen', data = df2, ax=ax)
plt.close(2)

# %%
gen = Genredf.groupby('Genre')[['Director_Count', 'Writer_Count']].mean()

# %%
Genredf.groupby('Genre')[['Director_Count', 'Writer_Count']].count()
# Out:
#              Director_Count  Writer_Count
# Genre
# Action                  935           935
# Adventure               601           601
# Animation               204           204
# Biography               405           405
# Comedy                 1260          1260
# Crime                   554           554
# Documentary             666           666
# Drama                  2765          2765
# Family                  231           231
# Fantasy                 260           260
# History                 190           190
# Horror                  448           448
# Music                   178           178
# Musical                  44            44
# Mystery                 330           330
# Romance                 639           639
# Sci-Fi                  235           235
# Sport                    97            97
# Thriller                750           750
# War                      90            90
# Western                  35            35

# %%
sns.catplot(x='Director_Count', y='Writer_Count', hue='Genre' ,kind='bar', data=refined)

# %%
refined =Genredf.loc[(Genredf['Genre'] == 'Musical')|(Genredf['Genre'] == 'Adventure')|
                    (Genredf['Genre'] == 'Animation')|(Genredf['Genre'] == 'Action')|
                    (Genredf['Genre'] == 'Fantasy')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2a6dde88663c> in <module>
# ----> 1 refined =Genredf.loc[(Genredf['Genre'] == 'Musical')|(Genredf['Genre'] == 'Adventure')|
#       2                     (Genredf['Genre'] == 'Animation')|(Genredf['Genre'] == 'Action')|
#       3                     (Genredf['Genre'] == 'Fantasy')]
#
# NameError: name 'Genredf' is not defined

# %%
Action, Adventure, Animation

# %%
refined.head()
# Out:
#               Title    Genre  Domestic_Gross  Foreign_Gross  Worldwide_Gross  \
# 0        Cinderella  Musical     201151353.0    333400000.0      534551353.0
# 1        Cinderella  Musical      85000000.0    178591415.0      263591415.0
# 2      My Fair Lady  Musical      72000000.0        71636.0       72071636.0
# 3         Burlesque  Musical      39400000.0     50100000.0       90552675.0
# 4  Standing Ovation  Musical        531806.0            0.0         531806.0
#
#    Production_Budget  Director_Count  Writer_Count
# 0         95000000.0               1             1
# 1          2900000.0               1             1
# 2         17000000.0               1             1
# 3         55000000.0               1             1
# 4          5600000.0               1             1

# %%
refined['Genre'].value_counts()
# Out:
# Action       935
# Adventure    601
# Fantasy      260
# Sci-Fi       235
# Animation    204
# Name: Genre, dtype: int64
